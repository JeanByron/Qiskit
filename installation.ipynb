# %%
import qiskit

# %%
qiskit.__version__
# Out:
# '2.5.2'

# %%
from qiskit_ibm_runtime import QiskitRuntimeService

service = QiskitRuntimeService("ibm_quantum",#ibm cloud
                               token=)
