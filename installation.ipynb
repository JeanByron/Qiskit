# %%
import qiskit

# %%
qiskit.__version__
# Out:
# '2.5.2'

# %%
import os
from dotenv import load_dotenv
from qiskit_ibm_runtime import QiskitRuntimeService

load_dotenv()

service = QiskitRuntimeService(
    channel="ibm_quantum_platform",
    token=os.getenv("QISKIT_IBM_TOKEN"),
    instance=os.getenv("QISKIT_IBM_INSTANCE")
)
# Out:
# qiskit_runtime_service._discover_account:WARNING:2026-09-14 14:35:55,857: Loading account with the given token. A saved account will not be used.
# ---------------------------------------------------------------------------
# IBMInputValueError                        Traceback (most recent call last)
# Cell In[8], line 7
#       3 from qiskit_ibm_runtime import QiskitRuntimeService
#       4
#       5 load_dotenv()
#       6
# ----> 7 service = QiskitRuntimeService(
#       8     channel="ibm_quantum_platform",
#       9     token=os.getenv("QISKIT_IBM_TOKEN"),
#      10     instance=os.getenv("QISKIT_IBM_INSTANCE")
#
# File ~\miniconda3\envs\qiskit\Lib\site-packages\qiskit_ibm_runtime\qiskit_runtime_service.py:280, in QiskitRuntimeService.__init__(self, channel, token, url, filename, name, instance, proxies, verify, private_endpoint, url_resolver, region, plans_preference, tags)
#     278 else:
#     279     self._api_clients = {}
# --> 280     instance_backends = self._resolve_cloud_instances(instance)
#     281     instance_names = [instance.get("name") for instance in self._backend_instance_groups]
#     282     instance_plan_names = {
#     283         instance.get("plan") for instance in self._backend_instance_groups
#     284     }
#
# File ~\miniconda3\envs\qiskit\Lib\site-packages\qiskit_ibm_runtime\qiskit_runtime_service.py:707, in QiskitRuntimeService._resolve_cloud_instances(self, instance)
#     695 if not self._backend_instance_groups:
#     696     self._backend_instance_groups = [
#     697         {
#     698             "name": inst["name"],
#    (...)    705         for inst in self._all_instances
#     706     ]
# --> 707     self._filter_instances_by_saved_preferences()
#     709 return [(inst["crn"], inst["backends"]) for inst in self._backend_instance_groups]
#
# File ~\miniconda3\envs\qiskit\Lib\site-packages\qiskit_ibm_runtime\qiskit_runtime_service.py:393, in QiskitRuntimeService._filter_instances_by_saved_preferences(self)
#     391 if self._plans_preference:
#     392     error_string += f"plan: {self._plans_preference}"
# --> 393 raise IBMInputValueError(
#     394     "No matching instances found for the following filters:",
#     395     f"{error_string}.",
#     396 )
#
# IBMInputValueError: 'No matching instances found for the following filters: .'
